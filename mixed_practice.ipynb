# %% [markdown]
# # Mixed Practice: Assignment, Strings, Loops, Control Flow

# %% [markdown]
# Assign the value of the expression $\frac{3\times\left(2^5-3\right)^2}{5}$ to the variable `answer`

# %%
# DO NOT do the calculation by hand and then just store the result.
# DO write answer as a python expression. Mind your parens.
answer = None

# %% [markdown]
# For the string given, starting with the third letter, print out every third letter.
# **example:** `"excelsior!"` -> `"csr"`

# %%
given = "Homestar Runner"
# Your print statement here:

# %% [markdown]
# Modify the string provided (make it an f-string) to print out the variable `secret` in reverse after "is".

# %%
password = "riahdrib" # do not modify this line
print("The password is ") # you may change this line
# Out:
# The password is

# %% [markdown]
# Write an `if` statement that prints "sevenish" if `n` is a multiple of 7 and "boring" otherwise.

# %%
n = 613579
# Your if statement here:

# %% [markdown]
# Write a `for` loop that prints each word in `triple_me` three times on a separate line.
# The solution should print:
#
# `"foofoofoo"`
#
# `"barbarbar"`
#
# `"bazbazbaz"`

# %%
triple_me = ["foo", "bar", "baz"]
# Your for loop here:

# %% [markdown]
# Write a function `lattice_points` that takes as input two integers `a` and `b`, and returns a list of every **lattice point** inside or on the rectangle defined by the points $(0, 0)$ and $(a, b)$. For example, `lattice_points(1, 2)` should return:
#
#  `[(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)]`

# %%
def lattice_points(a, b):
    #delete "pass" when you work on this
    pass
